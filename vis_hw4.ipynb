# %% [markdown]
# <a href="https://colab.research.google.com/github/tigon4ik/vis_hw/blob/hw4/vis_hw4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## t-SNE
# ### Дарбинян Оганес

# %%
# !git clone https://github.com/tigon4ik/vis_hw.git && cd vis_hw && git checkout hw4
# Out:
# Cloning into 'vis_hw'...
# remote: Enumerating objects: 43, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 43 (delta 13), reused 4 (delta 0), pack-reused 0
# Unpacking objects: 100% (43/43), done.
# Branch 'hw4' set up to track remote branch 'hw4' from 'origin'.
# Switched to a new branch 'hw4'

# %%
from sklearn.datasets import load_digits
import numpy as np
import pylab

# %%
def Hbeta(D=np.array([]), beta=1.0):
    P = np.exp(-D.copy() * beta)
    sumP = sum(P)
    H = np.log(sumP) + beta * np.sum(D * P) / sumP
    P = P / sumP
    return H, P

# %%
def x2p(X=np.array([]), tol=1e-5, perplexity=30.0):
    print("Computing pairwise distances...")
    (n, d) = X.shape
    sum_X = np.sum(np.square(X), 1)
    D = np.add(np.add(-2 * np.dot(X, X.T), sum_X).T, sum_X)
    P = np.zeros((n, n))
    beta = np.ones((n, 1))
    logU = np.log(perplexity)
    for i in range(n):
        if i % 500 == 0:
            print("Computing P-values for point {} of {}..." .format(i, n))

        betamin = -np.inf
        betamax = np.inf
        Di = D[i, np.concatenate((np.r_[0:i], np.r_[i+1:n]))]
        (H, thisP) = Hbeta(Di, beta[i])

        Hdiff = H - logU
        tries = 0
        while np.abs(Hdiff) > tol and tries < 50:

            if Hdiff > 0:
                betamin = beta[i].copy()
                if betamax == np.inf or betamax == -np.inf:
                    beta[i] = beta[i] * 2.
                else:
                    beta[i] = (beta[i] + betamax) / 2.
            else:
                betamax = beta[i].copy()
                if betamin == np.inf or betamin == -np.inf:
                    beta[i] = beta[i] / 2.
                else:
                    beta[i] = (beta[i] + betamin) / 2.

            (H, thisP) = Hbeta(Di, beta[i])
            Hdiff = H - logU
            tries += 1

        P[i, np.concatenate((np.r_[0:i], np.r_[i+1:n]))] = thisP

    print("Mean value of sigma: {}".format(np.mean(np.sqrt(1 / beta))))
    return P

# %%
def pca(X=np.array([]), no_dims=50):
    print("Preprocessing the data using PCA...")
    (n, d) = X.shape
    X = X - np.tile(np.mean(X, 0), (n, 1))
    (l, M) = np.linalg.eig(np.dot(X.T, X))
    Y = np.dot(X, M[:, 0:no_dims])
    return Y

# %%
def tsne(X=np.array([]), no_dims=2, initial_dims=50, perplexity=30.0):
    if isinstance(no_dims, float):
        print("Error: array X should have type float.")
        return -1
    if round(no_dims) != no_dims:
        print("Error: number of dimensions should be an integer.")
        return -1

    X = pca(X, initial_dims).real
    (n, d) = X.shape
    max_iter = 1000
    initial_momentum = 0.5
    final_momentum = 0.8
    eta = 500
    min_gain = 0.01
    Y = np.random.randn(n, no_dims)
    dY = np.zeros((n, no_dims))
    iY = np.zeros((n, no_dims))
    gains = np.ones((n, no_dims))

    P = x2p(X, 1e-5, perplexity)
    P = P + np.transpose(P)
    P = P / np.sum(P)
    P = P * 4.
    P = np.maximum(P, 1e-12)

    for iter in range(max_iter):

        sum_Y = np.sum(np.square(Y), 1)
        num = -2. * np.dot(Y, Y.T)
        num = 1. / (1. + np.add(np.add(num, sum_Y).T, sum_Y))
        num[range(n), range(n)] = 0.
        Q = num / np.sum(num)
        Q = np.maximum(Q, 1e-12)

        PQ = P - Q
        for i in range(n):
            dY[i, :] = np.sum(np.tile(PQ[:, i] * num[:, i], (no_dims, 1)).T * (Y[i, :] - Y), 0)

        if iter < 20:
            momentum = initial_momentum
        else:
            momentum = final_momentum
        gains = (gains + 0.2) * ((dY > 0.) != (iY > 0.)) + \
                (gains * 0.8) * ((dY > 0.) == (iY > 0.))
        gains[gains < min_gain] = min_gain
        iY = momentum * iY - eta * (gains * dY)
        Y = Y + iY
        Y = Y - np.tile(np.mean(Y, 0), (n, 1))

        if (iter + 1) % 10 == 0:
            C = np.sum(P * np.log(P / Q))
            print("Iteration {}: error is {}".format(iter + 1, C))

        if iter == 100:
            P = P / 4.

    return Y

# %%
X = np.loadtxt("vis_hw/mnist2500_X.txt")
labels = np.loadtxt("vis_hw/mnist2500_labels.txt")
Y = tsne(X, 2, 50, 20.0)
# Out:
# Preprocessing the data using PCA...
# Computing pairwise distances...
# Computing P-values for point 0 of 2500...
# Computing P-values for point 500 of 2500...
# Computing P-values for point 1000 of 2500...
# Computing P-values for point 1500 of 2500...
# Computing P-values for point 2000 of 2500...
# Mean value of sigma: 2.386596621341598
# Iteration 10: error is 23.80265306934657
# Iteration 20: error is 21.551784136290447
# Iteration 30: error is 18.11566988131871
# Iteration 40: error is 16.818633163496468
# Iteration 50: error is 16.415697337192846
# Iteration 60: error is 16.204733183084475
# Iteration 70: error is 16.115024123278786
# Iteration 80: error is 16.039981192777777
# Iteration 90: error is 15.980990230413644
# Iteration 100: error is 15.937185115199537
# Iteration 110: error is 2.3202879284337175
# Iteration 120: error is 2.0813998947737495
# Iteration 130: error is 1.8979839545366992
# Iteration 140: error is 1.758957693674659
# Iteration 150: error is 1.6519309629945775
# Iteration 160: error is 1.568394304512446
# Iteration 170: error is 1.5014380046203368
# Iteration 180: error is 1.4467291903425332
# Iteration 190: error is 1.4012470568163315
# Iteration 200: error is 1.3629283993640102
# Iteration 210: error is 1.3300471799593
# Iteration 220: error is 1.3024630967204338
# Iteration 230: error is 1.278834122210044
# Iteration 240: error is 1.2582762266582508
# Iteration 250: error is 1.2401942650993132
# Iteration 260: error is 1.2240308110260996
# Iteration 270: error is 1.2095061566950764
# Iteration 280: error is 1.1965311704478467
# Iteration 290: error is 1.1847851491442567
# Iteration 300: error is 1.174162671629697
# Iteration 310: error is 1.164573214775393
# Iteration 320: error is 1.1558587926358654
# Iteration 330: error is 1.1478776363975114
# Iteration 340: error is 1.1405319404573333
# Iteration 350: error is 1.1337475521816256
# Iteration 360: error is 1.1274687571986826
# Iteration 370: error is 1.1216447780639862
# Iteration 380: error is 1.1162116524082808
# Iteration 390: error is 1.1111525138085703
# Iteration 400: error is 1.1064309762381357
# Iteration 410: error is 1.102019574112811
# Iteration 420: error is 1.0978932871179907
# Iteration 430: error is 1.0940311339050666
# Iteration 440: error is 1.0904020484998846
# Iteration 450: error is 1.0869795825363147
# Iteration 460: error is 1.083751718396879
# Iteration 470: error is 1.0806937089837274
# Iteration 480: error is 1.0777984529313562
# Iteration 490: error is 1.0750604665276555
# Iteration 500: error is 1.0724676689448471
# Iteration 510: error is 1.0700163839166745
# Iteration 520: error is 1.0676845122328653
# Iteration 530: error is 1.0654585340525937
# Iteration 540: error is 1.0633365658735487
# Iteration 550: error is 1.061311374182482
# Iteration 560: error is 1.0593798877638014
# Iteration 570: error is 1.0575302164223177
# Iteration 580: error is 1.0557657255715052
# Iteration 590: error is 1.054080862311893
# Iteration 600: error is 1.0524622517043127
# Iteration 610: error is 1.0509050171758854
# Iteration 620: error is 1.0494093869442005
# Iteration 630: error is 1.0479702023568247
# Iteration 640: error is 1.0465894054594795
# Iteration 650: error is 1.0452734285852274
# Iteration 660: error is 1.0440157497931017
# Iteration 670: error is 1.0428063373722154
# Iteration 680: error is 1.0416435287610957
# Iteration 690: error is 1.0405222348580014
# Iteration 700: error is 1.0394363642466322
# Iteration 710: error is 1.0383872403700032
# Iteration 720: error is 1.0373771189237386
# Iteration 730: error is 1.0364008059570986
# Iteration 740: error is 1.035456021560296
# Iteration 750: error is 1.0345450009271242
# Iteration 760: error is 1.0336649217692622
# Iteration 770: error is 1.0328134752758251
# Iteration 780: error is 1.0320029452015513
# Iteration 790: error is 1.0312167056360144
# Iteration 800: error is 1.0304540855144648
# Iteration 810: error is 1.0297158598837524
# Iteration 820: error is 1.028998787117504
# Iteration 830: error is 1.0283008330802426
# Iteration 840: error is 1.027620817762317
# Iteration 850: error is 1.026956511941242
# Iteration 860: error is 1.0263052053138608
# Iteration 870: error is 1.025667508799035
# Iteration 880: error is 1.025050465107117
# Iteration 890: error is 1.0244546719707448
# Iteration 900: error is 1.023880287938848
# Iteration 910: error is 1.0233234633230934
# Iteration 920: error is 1.0227821298481716
# Iteration 930: error is 1.022256790566157
# Iteration 940: error is 1.0217459598859455
# Iteration 950: error is 1.021247392117034
# Iteration 960: error is 1.0207603640424436
# Iteration 970: error is 1.0202860925269053
# Iteration 980: error is 1.019822625508061
# Iteration 990: error is 1.0193700169404774
# Iteration 1000: error is 1.018928575026093

# %%
pylab.figure(dpi = 150)
pylab.scatter(Y[:, 0], Y[:, 1], 20, labels)
pylab.show()
